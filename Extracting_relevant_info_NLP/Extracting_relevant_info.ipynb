# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
raw_job_titles = [
    {
        "title": "Chief Technology Officer",
        "responsibility": "Overseeing technology and IT strategy",
        "department": "Technology"
    },
    {
        "title": "Product Manager",
        "responsibility": "Managing product development",
        "department": "Product Management"
    },
    {
        "title": "Software Engineer",
        "responsibility": "Developing software applications",
        "department": "Engineering"
    },
    {
        "title": "Data Scientist",
        "responsibility": "Analyzing data and creating models",
        "department": "Data Science"
    },
    {
        "title": "Marketing Director",
        "responsibility": "Leading marketing efforts",
        "department": "Marketing"
    },
    {
        "title": "Chief Financial Officer",
        "responsibility": "Managing financial operations",
        "department": "Finance"
    },
    {
        "title": "HR Manager",
        "responsibility": "Managing human resources",
        "department": "Human Resources"
    },
    {
        "title": "Sales Representative",
        "responsibility": "Selling products or services",
        "department": "Sales"
    },
    {
        "title": "Graphic Designer",
        "responsibility": "Creating visual designs",
        "department": "Design"
    },
    {
        "title": "CEO",
        "responsibility": "Overseeing the entire company",
        "department": "Executive"
    },
    {
        "title": "Research Scientist",
        "responsibility": "Conducting research and experiments",
        "department": "Research"
    },
    {
        "title": "Customer Support Specialist",
        "responsibility": "Assisting customers with issues",
        "department": "Customer Support"
    },
    {
        "title": "Project Manager",
        "responsibility": "Managing projects and teams",
        "department": "Project Management"
    },
    {
        "title": "Content Writer",
        "responsibility": "Creating written content",
        "department": "Content"
    },
    {
        "title": "Operations Manager",
        "responsibility": "Overseeing daily operations",
        "department": "Operations"
    },
    {
        "title": "UX/UI Designer",
        "responsibility": "Designing user interfaces",
        "department": "Design"
    },
    {
        "title": "Legal Counsel",
        "responsibility": "Providing legal advice",
        "department": "Legal"
    },
    {
        "title": "Quality Assurance Analyst",
        "responsibility": "Testing software for quality",
        "department": "Quality Assurance"
    },
    {
        "title": "IT Support Specialist",
        "responsibility": "Providing technical support",
        "department": "IT"
    },
    {
        "title": "Social Media Manager",
        "responsibility": "Managing social media accounts",
        "department": "Marketing"
    },
    {
        "title": "Supply Chain Analyst",
        "responsibility": "Analyzing supply chain data",
        "department": "Supply Chain"
    },
    {
        "title": "Customer Success Manager",
        "responsibility": "Ensuring customer satisfaction",
        "department": "Customer Success"
    },
    {
        "title": "Data Analyst",
        "responsibility": "Analyzing data for insights",
        "department": "Data Analysis"
    },
    {
        "title": "Accountant",
        "responsibility": "Managing financial records",
        "department": "Finance"
    },
    {
        "title": "Software Architect",
        "responsibility": "Designing software architecture",
        "department": "Engineering"
    },
    {
        "title": "Business Development Manager",
        "responsibility": "Developing business strategies",
        "department": "Business Development"
    },
    {
        "title": "Nurse",
        "responsibility": "Providing healthcare services",
        "department": "Healthcare"
    },
    {
        "title": "Mechanical Engineer",
        "responsibility": "Designing mechanical systems",
        "department": "Engineering"
    },
    {
        "title": "UX Researcher",
        "responsibility": "Conducting user research",
        "department": "User Experience"
    },
    {
        "title": "Network Administrator",
        "responsibility": "Managing network infrastructure",
        "department": "IT"
    },
    {
        "title": "Teacher",
        "responsibility": "Educating students",
        "department": "Education"
    },
    {
        "title": "Digital Marketing Specialist",
        "responsibility": "Implementing digital marketing campaigns",
        "department": "Marketing"
    },
    {
        "title": "Pharmacist",
        "responsibility": "Dispensing medications",
        "department": "Pharmacy"
    },
    {
        "title": "Architect",
        "responsibility": "Designing architectural plans",
        "department": "Architecture"
    },
    {
        "title": "Customer Service Representative",
        "responsibility": "Assisting customers with inquiries",
        "department": "Customer Service"
    },
    {
        "title": "Data Engineer",
        "responsibility": "Building data pipelines",
        "department": "Data Engineering"
    },
    {
        "title": "Public Relations Specialist",
        "responsibility": "Managing public relations efforts",
        "department": "Public Relations"
    },
    {
        "title": "Chef",
        "responsibility": "Preparing food in a restaurant",
        "department": "Culinary"
    },
    {
        "title": "Graphic Artist",
        "responsibility": "Creating digital artwork",
        "department": "Design"
    },
    {
        "title": "Mechatronics Engineer",
        "responsibility": "Designing mechatronic systems",
        "department": "Engineering"
    },
    {
        "title": "Librarian",
        "responsibility": "Managing library resources",
        "department": "Library"
    },
    {
        "title": "Fitness Trainer",
        "responsibility": "Providing fitness guidance",
        "department": "Fitness"
    },
    {
        "title": "Environmental Scientist",
        "responsibility": "Studying environmental data",
        "department": "Environmental Science"
    },
    {
        "title": "Business Analyst",
        "responsibility": "Analyzing business processes",
        "department": "Business Analysis"
    },
    {
        "title": "Dentist",
        "responsibility": "Providing dental care",
        "department": "Dentistry"
    },
    {
        "title": "Content Manager",
        "responsibility": "Managing digital content",
        "department": "Content Management"
    },
    {
        "title": "Financial Analyst",
        "responsibility": "Analyzing financial data",
        "department": "Finance"
    },
    {
        "title": "Art Director",
        "responsibility": "Overseeing creative projects",
        "department": "Art"
    },
    {
        "title": "HR Coordinator",
        "responsibility": "Coordinating HR activities",
        "department": "Human Resources"
    },
    {
        "title": "Web Developer",
        "responsibility": "Developing websites and web applications",
        "department": "Web Development"
    },
    {
        "title": "Supply Chain Manager",
        "responsibility": "Managing supply chain operations",
        "department": "Supply Chain"
    },
    {
        "title": "Customer Experience Specialist",
        "responsibility": "Enhancing customer experience",
        "department": "Customer Experience"
    },
     {
        "title": "Mobile App Developer",
        "responsibility": "Developing mobile applications",
        "department": "Mobile Development"
    },
    {
        "title": "Operations Coordinator",
        "responsibility": "Coordinating daily operations",
        "department": "Operations"
    },
    {
        "title": "Civil Engineer",
        "responsibility": "Designing civil engineering projects",
        "department": "Civil Engineering"
    },
    {
        "title": "Event Planner",
        "responsibility": "Planning and organizing events",
        "department": "Event Management"
    },
    {
        "title": "Clinical Researcher",
        "responsibility": "Conducting clinical research",
        "department": "Clinical Research"
    },
    {
        "title": "Interior Designer",
        "responsibility": "Designing interior spaces",
        "department": "Interior Design"
    },
    {
        "title": "Pharmaceutical Sales Representative",
        "responsibility": "Selling pharmaceutical products",
        "department": "Sales"
    },
    {
        "title": "Security Analyst",
        "responsibility": "Analyzing security threats",
        "department": "Security"
    },
    {
        "title": "Digital Artist",
        "responsibility": "Creating digital artwork and illustrations",
        "department": "Art"
    },
    {
        "title": "Research Analyst",
        "responsibility": "Analyzing data and market trends",
        "department": "Market Research"
    },
    {
        "title": "Cybersecurity Specialist",
        "responsibility": "Securing computer systems",
        "department": "Cybersecurity"
    },
    {
        "title": "Supply Chain Analyst",
        "responsibility": "Analyzing supply chain data",
        "department": "Supply Chain"
    },
    {
        "title": "Nutritionist",
        "responsibility": "Providing dietary guidance",
        "department": "Nutrition"
    },
    {
        "title": "Mechanical Designer",
        "responsibility": "Designing mechanical components",
        "department": "Mechanical Engineering"
    },
    {
        "title": "Social Worker",
        "responsibility": "Providing social services",
        "department": "Social Services"
    },
    {
        "title": "UX Designer",
        "responsibility": "Designing user experiences",
        "department": "User Experience"
    },
    {
        "title": "Supply Chain Manager",
        "responsibility": "Managing supply chain operations",
        "department": "Supply Chain"
    },
    {
        "title": "Investment Analyst",
        "responsibility": "Analyzing investment opportunities",
        "department": "Finance"
    },
    {
        "title": "Technical Support Engineer",
        "responsibility": "Providing technical support",
        "department": "Technical Support"
    },
    {
        "title": "Digital Marketing Manager",
        "responsibility": "Managing digital marketing campaigns",
        "department": "Marketing"
    },
    {
        "title": "Geologist",
        "responsibility": "Studying the Earth's structure",
        "department": "Geology"
    },
    {
        "title": "Fashion Designer",
        "responsibility": "Creating fashion designs",
        "department": "Fashion Design"
    },
    {
        "title": "Financial Advisor",
        "responsibility": "Providing financial advice",
        "department": "Finance"
    },
    {
        "title": "Registered Nurse",
        "responsibility": "Providing healthcare services",
        "department": "Healthcare"
    },
    {
        "title": "Artificial Intelligence Engineer",
        "responsibility": "Developing AI algorithms",
        "department": "AI Research"
    },
    {
        "title": "Software Quality Assurance Analyst",
        "responsibility": "Testing software for quality",
        "department": "Quality Assurance"
    },
    {
        "title": "Business Development Executive",
        "responsibility": "Developing business strategies",
        "department": "Business Development"
    },
    {
        "title": "Travel Agent",
        "responsibility": "Planning travel itineraries",
        "department": "Travel Services"
    },
    {
        "title": "Environmental Engineer",
        "responsibility": "Addressing environmental concerns",
        "department": "Environmental Engineering"
    },
    {
        "title": "Healthcare Administrator",
        "responsibility": "Managing healthcare facilities",
        "department": "Healthcare Management"
    },
    {
        "title": "Copywriter",
        "responsibility": "Creating written content",
        "department": "Content Creation"
    },
    {
        "title": "Physiotherapist",
        "responsibility": "Providing physical therapy",
        "department": "Physical Therapy"
    },
    {
        "title": "Mechanical Technician",
        "responsibility": "Assisting in mechanical tasks",
        "department": "Mechanical Engineering"
    },
    {
        "title": "Customer Relations Manager",
        "responsibility": "Managing customer relations",
        "department": "Customer Relations"
    },
    {
        "title": "Laboratory Technician",
        "responsibility": "Conducting lab tests",
        "department": "Laboratory Services"
    },
    {
        "title": "Legal Counsel",
        "responsibility": "Providing legal advice",
        "department": "Legal"
    },
    {
        "title": "Sales Representative",
        "responsibility": "Selling products or services",
        "department": "Sales"
    },
    {
        "title": "Architect",
        "responsibility": "Designing architectural structures",
        "department": "Architecture"
    },
    {
        "title": "Photographer",
        "responsibility": "Capturing photographs",
        "department": "Photography"
    },
    {
        "title": "Software Developer",
        "responsibility": "Developing software applications",
        "department": "Software Development"
    },
    {
        "title": "Human Resources Manager",
        "responsibility": "Managing HR operations",
        "department": "Human Resources"
    },
    {
        "title": "Research Scientist",
        "responsibility": "Conducting scientific research",
        "department": "Research"
    },
    {
        "title": "Economist",
        "responsibility": "Analyzing economic data",
        "department": "Economics"
    },
    {
        "title": "Customer Support Specialist",
        "responsibility": "Providing customer support",
        "department": "Customer Support"
    },
    {
        "title": "Civil Engineering Technician",
        "responsibility": "Assisting in civil engineering tasks",
        "department": "Civil Engineering"
    },
    {
        "title": "Brand Manager",
        "responsibility": "Managing brand strategies",
        "department": "Marketing"
    },
    {
        "title": "Biomedical Engineer",
        "responsibility": "Designing biomedical equipment",
        "department": "Biomedical Engineering"
    },
    {
        "title": "Graphic Designer",
        "responsibility": "Creating graphic designs",
        "department": "Graphic Design"
    },
    {
        "title": "Medical Doctor",
        "responsibility": "Providing medical care",
        "department": "Medicine"
    }
]
len(raw_job_titles)
# Out:
# 101

# %%
import re
import nltk
from nltk.corpus import stopwords
import pandas as pd
stop_words = set(stopwords.words("english"))


def get_first_title(title):
    # keep "co-founder, co-ceo, etc"
    title = re.sub(r"[Cc]o[\-\ ]","", title)
    split_titles = re.split(r"\,|\-|\||\&|\:|\/|and", title)
    return split_titles[0].strip()


def get_title_features(title):
    features = {}
    word_tokens = nltk.word_tokenize(title)
    filtered_words = [w for w in word_tokens if not w in stop_words]
    for word in filtered_words:
        features['contains({})'.format(word.lower())] = True
    if len(filtered_words) > 0:
        first_key = 'first({})'.format(filtered_words[0].lower())
        last_key = 'last({})'.format(filtered_words[-1].lower())
        features[first_key] = True
        features[last_key] = True
    return features

## build feature sets
# Responsibilities
responsibilities_features = [
    (
         get_title_features(job_title["title"]),
         job_title["responsibility"]
    )
    for job_title in raw_job_titles
    if job_title["responsibility"] is not None
]

# Departments
departments_features = [
    (
         get_title_features(job_title["title"]),
         job_title["department"]
    )
    for job_title in raw_job_titles
    if job_title["department"] is not None
]

## Train classifier
# Responsibilities
r_size = int(len(responsibilities_features) * 0.5)
r_train_set = responsibilities_features[r_size:]
r_test_set = responsibilities_features[:r_size]
responsibilities_classifier = nltk.NaiveBayesClassifier.train(
    r_train_set
)
print("Responsibility classification accuracy: {}".format(
    nltk.classify.accuracy(
        responsibilities_classifier,
        r_test_set
    )
))

# Departments
d_size = int(len(departments_features) * 0.5)
d_train_set = departments_features[d_size:]
d_test_set = departments_features[:d_size]
departments_classifier = nltk.NaiveBayesClassifier.train(
    d_train_set
)
print("Department classification accuracy: {}".format(
    nltk.classify.accuracy(
        departments_classifier,
        d_test_set
    )
))

## Test Classifier
title = "Making Payment Simpier Sambhav Pay +91-8882484147 ops@sambhavpay.com www.sambhavpay.com Gurugram -122016, Haryana B21, Phase-5, Udyog Vihar, BUSINESS HEAD Mrs. Sapna Raghav"
# title = "Director of Communications"
responsibility = responsibilities_classifier.classify(
    get_title_features(title)
)
department = departments_classifier.classify(
    get_title_features(title)
)
print("Job title: '{}'".format(title))
print("Responsibility: '{}'".format(responsibility))
print("Department: '{}'".format(department))

## Grade Classifier
# Responsibility
responsibility_probability = \
    responsibilities_classifier.prob_classify(
        get_title_features(title)
    )
responsibility_probability = 100 * responsibility_probability.prob(
    responsibility_probability.max()
)
print("Responsibility confidence: {}%".format(
    round(responsibility_probability)
))
# Department
department_probability = \
    departments_classifier.prob_classify(
        get_title_features(title)
    )
department_probability = 100 * department_probability.prob(
    department_probability.max()
)
print("Department confidence: {}%".format(
    round(department_probability)
))
# Out:
# Responsibility classification accuracy: 0.12
# Department classification accuracy: 0.28
# Job title: 'Making Payment Simpier Sambhav Pay +91-8882484147 ops@sambhavpay.com www.sambhavpay.com Gurugram -122016, Haryana B21, Phase-5, Udyog Vihar, BUSINESS HEAD Mrs. Sapna Raghav'
# Responsibility: 'Developing business strategies'
# Department: 'Business Development'
# Responsibility confidence: 6%
# Department confidence: 6%

# %%
training_data = [
    ("Making Payment Simpier Sambhav Pay +91-8882484147 ops@sambhavpay.com www.sambhavpay.com Gurugram -122016, Haryana B21, Phase-5, Udyog Vihar, BUSINESS HEAD Mrs. Sapna Raghav",
     {"entities": [(140, 151, "job_title")]}),

    ("Making Payment Simpter Sambhav Pay +91-7065483258 ops@sambhavpay.com www.sambhavpay.com Gurugram -122016, Haryana B21, Phase-5, Udyog Vihar, BUSINESS HEAD Mrs. Sapna Raghav",
     {"entities": [(140, 151, "job_title")]}),

    ("Vaibhavi Kamath Executive Assistant to CEO KNIGHT FINTECH +919136706988 vaibhavi@knightfintech.com www.knightfintech.com Empowering you by digital transformation",
     {"entities": [(29, 58, "job_title")]}),

    ("aytring Debal Chakraborty Co-Founder OFfice : Plot No. 8 &9, MM Towers debal@paytringcom Sector-18 Gurgaon, Haryana l22002 www.paytring.com +91 9711192256",
     {"entities": [(26, 37, "job_title")]}),

    ("G +91 83296 07320 Chief Technology Officer Dheeraj Kumar",
     {"entities": [(30, 53, "job_title")]}),

    ("Mitasha Paintal Www.superscan.ai mitasha.paintal@orb0.ai SCAN SUPER +91-9326045689 Automation & Fintech Head- Enterprise Mitasha Paintal",
     {"entities": [(101, 119, "job_title")]}),

    ("A Specified User Under RBI CICRA Act 2005 Data and Insights Platform for Lenders Gurgaon 122102 Emaar Paim Square https://roopya.money Unit 1106 +91 96545 74921 pankaj@roopya.com KoOPYA Asst. Vice President- Sales Pankaj Chugh",
     {"entities": [(192, 216, "job_title")]}),

    ("sandhya@backspace-tech.com C+91 9176478565 in Head of Marketing & Content Sandhya Manikandan",
     {"entities": [(38, 61, "job_title")]}),

    ("Pay +91 9354230590 vikas.sahu@Payl 0.com Assistant Manager-Luxury Retail Vikas Sahu",
     {"entities": [(45, 63, "job_title")]}),

    ("Purvashi Lakhupota Manager - Partnerships purvashilakhupota @kme.in +91 88794 42966 LXme 11th Floor, Times Tower, Kamala City, Senapati Bapat Marg, Lower Parel, Mumbai, Maharashtra - 400013 www.Lxme.in India's 1st Financial Platform for Women",
     {"entities": [(0, 20, "job_title")]}),
    ("dheerajafinarkein.com G +91 83296 O7320 Chief Technology Officer Dheeraj Kumar",
     {"entities": [(31, 53, "job_title")]}),

    ("SIGNZY www.signzy.com +91-79968 65504 www.signzy.com sugandha.bs @signzy.com Awfis, 8th Floor, Tower-1, One International Center. Senapati Bapat Marg. Dadar (West), Prabhadevi. Mumbai - 400O13.",
     {"entities": [(0, 0, "job_title")]}),

    ("Mridul Manhas CO-FOUNDER & COO +91 99624 91614 mridul@finsire,com www.finsire.com 37/15, 2nd St, Sripuram, Balajl Nagar, Royapettah, Chennai, Tamil Nadu 600014",
     {"entities": [(16, 34, "job_title")]}),

    ("JPayPhi Naveen Naini AVP - Sales naveen.naini@phicommerce.com +91 98702 15425 www.phicommerce.com www.payphi.com PhiCommerce",
     {"entities": [(13, 23, "job_title")]}),

    ("WWw, DECENTRO TECH Raunak Dembla FOUNDING MEMBER +91 97315 95757 raunak@decentro.tech",
     {"entities": [(14, 29, "job_title")]}),

    ("instantpay +91 82377 40041 mandar.n@instantpay.in MANDAR NAVGHARE KEY ACCOUNT MANAGER Instantpay India Limited 4th Fioor, Kalpataru Prime, WIE, Thane (W), Maharashtra 400604, India www.instantpay. in",
     {"entities": [(40, 62, "job_title")]}),

    ("Purvashi Lakhupota Manager - Partnerships purvashilakhupota@kme.in +91 88794 42966 LXMe India's 1st Financial Platform for Women 1th Floor, Times Tower, Kamala City, Senapati Bapat Marg, Lower Parel, Mumbai, Maharashtra - 400013 www.xme.in",
     {"entities": [(0, 20, "job_title")]}),

    ("PUNE & AGARTALA, INDIA DHAKA, BANGLADESH HTTPS://WWW. TALKENGGLOBAL.COM SUBHRA.DEB @ TALKENGGLOBAL.COM -91-9436569542 -880-1306308657 Er. Subhra Deb in Founder & CEO BE (CSE), M.TECH (T), MBA (Marketing), PGD (GARD), PGD (IS)",
     {"entities": [(168, 181, "job_title")]}),

    ("+ Z X CV BNM 2123OBobble En/HUMI SDFGHJKL' A Q WERTY UIO P Hello! A +91 9899093323 A Daditya@bobble.ai critical decisions today! Identify the alpha for your Bobble Al Business Lead DaaS Aditya Nayal",
     {"entities": [(183, 195, "job_title")]}),

    ("WWW.tohands.in praveenOtohands.in 8433674298 Chief Everything Officer Praveen Mishra",
     {"entities": [(35, 59, "job_title")]}),

    ("mool Abhinav Nayar CEO 9 abhinav@mool.one 9+91 94313 00667",
     {"entities": [(11, 14, "job_title")]}),

    ("S.V. Road, Santa Cruz (West), Mumbai 400054. India. Mumbai Corporate Office: Plaza Asiad, Level 2, Junction of Station Road & INFIBEAM AVENUES LIMITED P +91 22 67425555 (Ext: 363) W www.ccavenue.com www.ia.ooo M +91 8591306250 E vineeta.dalmeida@avenues.info Strategic Alliance Partnerships Business Development Manager Vineeta Edward DalmeidaA AVENUES INFIBEAM",
     {"entities": [(120, 159, "job_title")]}),

    ("www.payaidpayments.com Phani.Teja@payaidpayments.com +91 7702001611 INDIA. Hyderabad - 500082, Somajiguda, 405, Garden Manor, Payd Private Limited PayAid Payments Phani Teja Direotor & Co-founder",
     {"entities": [(100, 120, "job_title")]}),

    ("+91 9177032914 koushik.ashnalli@t-hub.co Startup Innovation Associate KOUSHIK ASHNALLI",
     {"entities": [(35, 59, "job_title")]}),
]
